# %%
import pandas as pd

# %%
for stage in ['train', 'val', 'test']:
    path_to_metadata = f'/Users/caioseda/Documents/Trabalho/Tecgraf/projetos/dados_inca/metadados/video_frame_metadata_{stage}.csv'
    df = pd.read_csv(path_to_metadata)
    print(f'--- {stage} ---')

    target_split = df['target_path'].str.split('/')
    df['target_path'] = target_split.str[-4:].str.join('/')

    video_split = df['video_path'].str.split('/')
    df['video_path'] = video_split.str[-2:].str.join('/')

    image_split = df['image_path'].str.split('/')
    df['image_path'] = image_split.str[-4:].str.join('/')

    df['target_path']
    path_dados_inca = '/Users/caioseda/Documents/Trabalho/Tecgraf/projetos/dados_inca/'

    df['target_path'] = path_dados_inca + df['target_path']
    df['video_path'] = path_dados_inca + df['video_path']
    df['image_path'] = path_dados_inca + df['image_path']

    display(df['image_path'].iloc[0])
    display(df['video_path'].iloc[0])
    display(df['target_path'].iloc[0])  

    df.to_csv(path_to_metadata, index=False)
# Out:
# --- train ---
# '/Users/caioseda/Documents/Trabalho/Tecgraf/projetos/dados_inca/dataset_inca/train/data/v10_f18.png'
# '/Users/caioseda/Documents/Trabalho/Tecgraf/projetos/dados_inca/videos/10.avi'
# '/Users/caioseda/Documents/Trabalho/Tecgraf/projetos/dados_inca/dataset_inca/train/target/v10_f18.tif'
# --- val ---
# '/Users/caioseda/Documents/Trabalho/Tecgraf/projetos/dados_inca/dataset_inca/val/data/v101_f16.png'
# '/Users/caioseda/Documents/Trabalho/Tecgraf/projetos/dados_inca/videos/101.avi'
# '/Users/caioseda/Documents/Trabalho/Tecgraf/projetos/dados_inca/dataset_inca/val/target/v101_f16.tif'
# --- test ---
# '/Users/caioseda/Documents/Trabalho/Tecgraf/projetos/dados_inca/dataset_inca/test/data/v100_f10.png'
# '/Users/caioseda/Documents/Trabalho/Tecgraf/projetos/dados_inca/videos/100.avi'
# '/Users/caioseda/Documents/Trabalho/Tecgraf/projetos/dados_inca/dataset_inca/test/target/v100_f10.tif'
